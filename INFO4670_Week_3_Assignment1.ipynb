# %% [markdown]
# <a href="https://colab.research.google.com/github/caffeinated-beverage/Nikki_INFO4670_Fall2026/blob/main/INFO4670_Week_3_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 — Making Sense of Northgate through Visualization
# **INFO 4670 · Data Analysis and Knowledge Discovery**  ·  **Due: Sunday, 11:59 PM**
#
# **Name:** Nikki Singh    **Date:** 09/03/26
#
# **The situation.** The Provost's question stands: *which students are struggling, and can we see it earlier?* This week you answer it the way analysts do — not by reading rows, but by drawing the data. Every chart below is built by **adapting code from the Guided notebook**; the intellectual work is choosing the right chart and reading it honestly.
#
# **For every chart you make, you must:**
# 1. **Choose** the chart type that fits the variable(s) and the question.
# 2. **Build** it in Colab from the Northgate files.
# 3. **Label** it fully — title, axis labels, and units/legend. *An unlabeled chart is an unfinished chart.*
# 4. **Write a STAR story** underneath it — Scope · Track · Articulate · Respond (defined on the Concepts deck).
#
# **How to work:** run Setup and Load first. Then, for each question, copy the closest cell from the Guided notebook into the empty cell, adapt it, and fill in the STAR cell below it.
#
# **Submit:** push this notebook to GitHub and submit the **GitHub link** in Canvas. (See the setup doc: *Colab_GitHub_Setup_INFO4670_Fall2026*.)

# %% [markdown]
# ## Setup — run this first (you don't need to change it)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Northgate house style (optional, but keeps your charts consistent)
NAVY = "#22303A"
RUST = "#C0562F"
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"]   = (8, 5)
plt.rcParams["axes.titlesize"]   = 13
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## Load the data — run this, then look before you plot

# %%
# STEP 1 — get the data into this notebook. Pick ONE option, then run.

DATA_DIR = "."   # OPTION 2 (default) · drag the 3 CSVs into the file panel on the left

# OPTION 1 · read from Google Drive — uncomment and edit the path:
# from google.colab import drive
# drive.mount("/content/drive")
# DATA_DIR = "/content/drive/MyDrive/.../Data"

import os
students = pd.read_csv(os.path.join(DATA_DIR, "student_records.csv"))
weekly   = pd.read_csv(os.path.join(DATA_DIR, "weekly_activity.csv"))
students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# ...

# %%
# how many rows, which columns, what types?
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027 entries, 0 to 2026
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            2027 non-null   object
#  1   major                 2027 non-null   object
#  2   age                   2027 non-null   int64
#  3   housing               2027 non-null   object
#  4   commute_miles         2027 non-null   float64
#  5   work_hours_per_week   2027 non-null   int64
#  6   advisor_meetings      2027 non-null   int64
#  7   credits_attempted     2027 non-null   int64
#  8   final_gpa             2027 non-null   float64
#  9   study_hours_reported  1772 non-null   float64
#  10  enrollment_date       2027 non-null   object
#  11  dropped_out           2027 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 190.2+ KB

# %% [markdown]
# # Part A — Guided questions
# Build **one chart per question**. Each maps to one chart family from this week. Copy the closest Guided-notebook cell, adapt it, label it, then write its STAR story.

# %% [markdown]
# ### Q1 · One quantitative variable
# **How many hours per week do Northgate students work?** Describe what's typical, how spread out it is, and whether anyone stands apart.
# → *histogram* (add a *box plot* if it helps). Column: `work_hours_per_week` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots()
sns.histplot(data=students, x="work_hours_per_week", color=NAVY, ax=ax)
ax.set_title("Weekly Work Hours for Northgate Students")
ax.set_xlabel("Hours per Week")
ax.set_ylabel("Number of Students")
plt.show()

# %%
fig, ax = plt.subplots()
sns.boxplot(data=students, y="work_hours_per_week", color=NAVY, ax=ax)
ax.set_title("Weekly Work Hours for Northgate Students")
ax.set_ylabel("Hours per Week")
plt.show()

# %% [markdown]
# **STAR story — Q1** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# *   **Scope:** These charts analyze the "work_hours_per_week" quantitative column
# across all 2,027 enrolled students in the student_records.csv dataset.
# *   **Track:** How many hours per week do Northgate students typically work, how wide is the spread, and are there any outliers?
#
# *   **Articulate:** The histogram shows that the distribution is multimodal with notable peaks at 0 hours, 15 hours, and 20 hours, with a smaller cluster near full-time 40 hours. The box plot shows that the typical student works a median of 18 hours, with the middle 50% (IQR) working between 10 and 25 hours per week.
# *   **Respond:** There are a few data points that contain impossible negative values, resulting in an inaccurate minimum value on both charts. These should be flagged as data-entry errors to be addressed and cleaned in the future. One thing I would look at next, seeing as there is a distinct cluster of students working 30 to 40 hours per week, is whether increased outside workloads correlate with lower GPAs, reduced study hours, and higher dropout rates.

# %% [markdown]
# ### Q2 · One categorical variable
# **How does enrollment compare across majors?**
# → *sorted bar chart*. Column: `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
order = students["major"].value_counts().index
fig, ax = plt.subplots()
sns.countplot(data=students, y="major", order=order, color=NAVY, ax=ax)
ax.set_title("Student Enrollment by Major at Northgate")
ax.set_xlabel("Number of Students")
ax.set_ylabel("Major")
plt.show()

# %% [markdown]
# **STAR story — Q2** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# *   **Scope:** This chart examines the "major" category column across all 2,027 enrolled students in the student_records.csv dataset.
# *   **Track:** How does student enrollment compare across different majors at Northgate?
#
# *   **Articulate:** Cybersecurity notably represents the largest student body with over 500 students. This is followed by Data Science, Information Science, and Information Technology which all sit just under 300. Next is Business Analytics at around 250 and Learning Technologies which is slightly above 200. The remaining tail consists of smaller counts for variations like "Cyber Security", "DataScience", "Information  Science", and "Info Technology" which all sit under a 100.
#
# *   **Respond:** This chart presents 10 distinct categories instead of the intended 6 due to inconsistent string formatting and duplicate entries (ex: using spaces and abbreviations). These should be flagged as data quality issues to be standardized in future data cleaning. Since computing and technology programs dominate enrollment in this dataset, I would look next at whether student retention (dropped_out) or GPA varies significantly across different major programs to determine if specific departments are experiencing disproportionate academic struggle.

# %% [markdown]
# ### Q3 · A quantity, split by category
# **Does final GPA differ across majors?** Read the exceptions, not just the boxes.
# → *box plot per major*. Columns: `final_gpa` and `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
order = students["major"].value_counts().index
fig, ax = plt.subplots(figsize=(9, 6))
sns.boxplot(data=students, x="final_gpa", y="major", order=order, color=NAVY, ax=ax)
ax.set_title("Final Cumulative GPA Across Majors")
ax.set_xlabel("Final Cumulative GPA (0.0 - 4.0)")
ax.set_ylabel("Major")
plt.show()

# %% [markdown]
# **STAR story — Q3** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# *   **Scope:** This chart shows the quantitative "final_gpa" (0.0 - 4.0) grouped by the categorical "major" column across all 2,027 students in the student_records.csv dataset.
# *   **Track:** Does final cumulative GPA differ across majors, and what outliers stand out from the central distributions?
# *   **Articulate:** Looking at all the boxes, typical academic performance is pretty much identical across all majors. Medians cluster tightly between 2.25 and 2.50, with the middle 50% (IQR) spanning roughly around 1.8 to 2.8 for each major. Having a specific major doesn't exclusively explain variations in GPA.
# *   **Respond:** Every single major has low-end outliers extending past the lower whiskers, with several students sitting at exactly 0.0 GPA. These should be flagged, since generally a 0.0 GPA reflects something else entirely. I would want to look at "dropped_out", "credits_attempted" and "minutes_active" for these specific students to see if these zeros point to early withdrawal rather than ordinary course struggle.

# %% [markdown]
# ### Q4 · Two quantitative variables
# **Is there a relationship between how far students commute and their final GPA?** Remember: *association is not causation.*
# → *scatterplot with a trend line*. Columns: `commute_miles` and `final_gpa` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots()
sns.regplot(data=students, x="commute_miles", y="final_gpa",
            scatter_kws={"s": 12, "color": NAVY, "alpha": 0.4},
            line_kws={"color": RUST}, ax=ax)
ax.set_title("Commute Distance vs. Final Cumulative GPA")
ax.set_xlabel("Commute Distance (Miles)")
ax.set_ylabel("Final Cumulative GPA (0.0 - 4.0)")
plt.show()

# %% [markdown]
# **STAR story — Q4** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# *   **Scope:** This chart analyzes the relationship between two continuous quantitative variables, "commute_miles" and "final_gpa", across all 2,027 students in the student_records.csv dataset.
# *   **Track:** Is there an observable relationship between how far students commute to campus and their final cumulative GPA?
# *   **Articulate:** The trendline displays a statistically weak to moderate negative linear association. It slopes downward, meaning students with shorter commutes do average a higher GPA compared to those with long commutes. However, there is substantial scattering of data points at every mile increment, showing that association does not imply direct causation.
# *   **Respond:** There are a few extreme outliers that commute between 50 and 80 miles, only one of which doesn't follow the negative trendline. We again see several students sitting at 0.0 exactly GPA, persisting across various distances. To obtain a stronger correlation between commute length and student struggle, I would look at housing arrangements, "work_hours_per_week", and "dropped_out" rates among long-distance commuters to see if transportation burdens or off-campus commitments explain the drop in GPA.

# %% [markdown]
# ### Q5 · Over time
# **How does student engagement change across the semester?**
# → *line chart* of average weekly activity. Use the `weekly` table: `week` and `minutes_active` (you'll need to average by week first — see the Guided notebook).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
weekly_avg = weekly.groupby("week")["minutes_active"].mean().reset_index()
fig, ax = plt.subplots()
sns.lineplot(data=weekly_avg, x="week", y="minutes_active",
             color=NAVY, marker="o", ax=ax)
ax.set_title("Average Weekly LMS Activity Across the Semester")
ax.set_xlabel("Week of Semester (1 - 16)")
ax.set_ylabel("Average Active Time (Minutes)")
plt.show()

# %% [markdown]
# **STAR story — Q5** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# *   **Scope:** This chart tracks the weekly_activity.csv (weekly) dataset across all 2,027 students over the course of the 16-week semester, using the variable "week" (1 to 16) and the quantitative metric "minutes_active" averaged by week.
# *   **Track:** How does student engagement (measured via active minutes) change across the duration of the semester?
# *   **Articulate:** Across almost the entire semester, average engagement remains very consistent, hovering around 210 minutes per week. However at Week 9, active time drops dramatically to under 90 minutes, before recovering to baseline in Week 10.
# *   **Respond:** The sharp drop in Week 9 likely corresponds to an academic calendar break (like Spring break or Thanksgiving Break) rather than mass student disengagement. Since aggregate averages mask individual struggles, I would want to see which individual students showed sustained disengagement past the temporary holiday dip.

# %% [markdown]
# # Part B — Your own question (open)
# Pose **one question of your own** about the Northgate students, choose the chart that answers it, build it, label it, and write its STAR story. Going beyond Part A is rewarded — a per-student line chart, a violin plot, or a chart of a messier column are all fair game.
#
# **Your question:** Does final GPA differ between students who drop out and students who stay enrolled?

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots()
sns.violinplot(data=students, x="dropped_out", y="final_gpa", color=NAVY, ax=ax)
ax.set_title("Final Cumulative GPA by Enrollment Status")
ax.set_xlabel("Enrollment Status")
ax.set_ylabel("Final Cumulative GPA (0.0 - 4.0)")
ax.set_xticks([0,1])
ax.set_xticklabels(["Enrolled", "Dropped Out"])
plt.show()

# %% [markdown]
# **STAR story — Part B** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# *   **Scope:** This chart looks at the continuous quantitative variable "final_gpa" grouped by the binary categorical indicator "dropped_out" (enrolled or dropped out) across all 2,027 students in the student_records.csv dataset.
# *   **Track:** Does final cumulative GPA differ between students who drop out and those who stay enrolled, and is academic failure the primary motive behind students who drop out?
# *   **Articulate:** Enrolled students have a higher median GPA of around 2.4 with a symmetric bell curve spanning mostly between 1.9 and 2.8. Students who have dropped out sit slightly lower, with a median GPA of around 2.1 and an IQR of 1.6 to 2.5. Both groups have a secondary density bulb at the bottom around 0.0 GPA.
# *   **Respond:** Interestingly and unexpectedly, a notable chunk of students who dropped out had a GPA of 2.5 or higher, meaning low GPA is not the only reason students drop out. We already looked at the impact of commute distance on GPA, so I would like to examine additional non-academic factors, such as "work_hours_per_week".

# %% [markdown]
# # Before you submit — checklist
# - [ ] The notebook **runs top to bottom** with no errors (Runtime → Restart and run all).
# - [ ] All **6 charts** are present, each with a title, labeled axes, and units/legend where needed.
# - [ ] Each chart has a **complete STAR story**, including any exceptions you spotted.
# - [ ] Part B question is written in and answered.
# - [ ] Pushed to **GitHub**, and the **GitHub link** is submitted in Canvas.
#
# **Rubric (70 pts):** chart choice 10 · correct build 20 · labeling 10 · STAR reading 18 · Part B question 4 · submission & professionalism 8.
